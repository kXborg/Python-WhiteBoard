# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('Quiz2_8.jpg', 0)
thresh = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 7, 10)
plt.figure(figsize=(15,15))
plt.imshow(thresh, cmap='gray')
